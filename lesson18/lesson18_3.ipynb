# %%
import numpy as np
import pandas as pd

scores = pd.DataFrame(np.random.randint(50,101,size=(50,5)),
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=range(1,51))
scores

# %%
def abc(s):
    return s.max()
scores.apply(abc)

# %%
def abc(s):
    return pd.Series([s.min(),s.max(),s.mean()],index=['最低分','最高分','平均'])
scores.apply(abc)

# %%
scores.index = scores.index.map(lambda i:f'{i}號')
scores

# %%
def abc1(item):
    less_student = item[item < 60]
    less_count = less_student.count()
    less_str = ",".join(less_student.index.values.tolist())
    
    return pd.Series([item.sum(),item.mean(),less_count,less_str],index=['總分','平均','不及格科目數','不及格科目'])
scores.apply(abc1,axis=1)
# Out:
#       總分    平均  不及格科目數     不及格科目
# 1號   387  77.4       2     國文,英文
# 2號   411  82.2       0
# 3號   349  69.8       0
# 4號   447  89.4       0
# 5號   372  74.4       0
# 6號   393  78.6       1        國文
# 7號   352  70.4       2     英文,地理
# 8號   363  72.6       1        地理
# 9號   363  72.6       1        地理
# 10號  393  78.6       0
# 11號  350  70.0       2     國文,數學
# 12號  337  67.4       2     國文,英文
# 13號  314  62.8       2     國文,地理
# 14號  411  82.2       0
# 15號  379  75.8       0
# 16號  409  81.8       0
# 17號  351  70.2       0
# 18號  410  82.0       0
# 19號  347  69.4       1        數學
# 20號  382  76.4       1        英文
# 21號  423  84.6       0
# 22號  352  70.4       1        地理
# 23號  359  71.8       1        英文
# 24號  371  74.2       1        國文
# 25號  382  76.4       0
# 26號  404  80.8       0
# 27號  420  84.0       0
# 28號  362  72.4       1        歷史
# 29號  300  60.0       3  英文,數學,地理
# 30號  377  75.4       0
# 31號  347  69.4       1        國文
# 32號  323  64.6       1        國文
# 33號  399  79.8       0
# 34號  356  71.2       2     數學,歷史
# 35號  383  76.6       1        英文
# 36號  384  76.8       1        國文
# 37號  395  79.0       1        地理
# 38號  414  82.8       0
# 39號  348  69.6       2     數學,地理
# 40號  363  72.6       1        數學
# 41號  380  76.0       1        地理
# 42號  344  68.8       1        國文
# 43號  307  61.4       2     國文,英文
# 44號  296  59.2       3  國文,數學,地理
# 45號  371  74.2       1        歷史
# 46號  375  75.0       1        地理
# 47號  404  80.8       1        國文
# 48號  392  78.4       1        英文
# 49號  423  84.6       0
# 50號  370  74.0       1        數學

# %%
one_student = scores.iloc[0]
less_student = one_student[one_student < 60]
less_student
# Out:
# 國文    57
# 英文    59
# Name: 1號, dtype: int32

# %%
less_student.count()
",".join(less_student.index.values.tolist())
# Out:
# '國文,英文'
